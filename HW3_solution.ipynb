# %% [markdown]
# # gd1_lab1_1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return x**3-2*x+100

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return 3*x**2-2

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x += v 
        #print(x)
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 2  
# 執行週期數
epochs = 1000 
# 學習率   
lr = 0.01   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-2, 2.0, 0.001)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [-0.5        -0.4875     -0.47462969 ...  0.81649658  0.81649658
#   0.81649658]

# %% [markdown]
# ## gd1_lab1_2

# %%
'''
修改 gd1.py 的損失函數如下，設定不同的起始點，是否可找到區域最小值(local minimum)
損失函數 = 2x4-3x2+2x-20
'''
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return -(-5*x**2+3*x+6)

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return 10*x-3 

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 5   
# 執行週期數
epochs = 200 
# 學習率   
lr = 0.01   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-5, 5.0, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [5.         4.53       4.107      3.7263     3.38367    3.075303
#  2.7977727  2.54799543 2.32319589 2.1208763  1.93878867 1.7749098
#  1.62741882 1.49467694 1.37520925 1.26768832 1.17091949 1.08382754
#  1.00544479 0.93490031 0.87141028 0.81426925 0.76284232 0.71655809
#  0.67490228 0.63741205 0.60367085 0.57330376 0.54597339 0.52137605
#  0.49923844 0.4793146  0.46138314 0.44524483 0.43072034 0.41764831
#  0.40588348 0.39529513 0.38576562 0.37718906 0.36947015 0.36252313
#  0.35627082 0.35064374 0.34557937 0.34102143 0.33691929 0.33322736
#  0.32990462 0.32691416 0.32422274 0.32180047 0.31962042 0.31765838
#  0.31589254 0.31430329 0.31287296 0.31158566 0.3104271  0.30938439
#  0.30844595 0.30760135 0.30684122 0.3061571  0.30554139 0.30498725
#  0.30448852 0.30403967 0.3036357  0.30327213 0.30294492 0.30265043
#  0.30238539 0.30214685 0.30193216 0.30173895 0.30156505 0.30140855
#  0.30126769 0.30114092 0.30102683 0.30092415 0.30083173 0.30074856
#  0.3006737  0.30060633 0.3005457  0.30049113 0.30044202 0.30039782
#  0.30035803 0.30032223 0.30029001 0.30026101 0.30023491 0.30021142
#  0.30019027 0.30017125 0.30015412 0.30013871 0.30012484 0.30011235
#  0.30010112 0.30009101 0.30008191 0.30007372 0.30006634 0.30005971
#  0.30005374 0.30004837 0.30004353 0.30003918 0.30003526 0.30003173
#  0.30002856 0.3000257  0.30002313 0.30002082 0.30001874 0.30001686
#  0.30001518 0.30001366 0.30001229 0.30001106 0.30000996 0.30000896
#  0.30000807 0.30000726 0.30000653 0.30000588 0.30000529 0.30000476
#  0.30000429 0.30000386 0.30000347 0.30000312 0.30000281 0.30000253
#  0.30000228 0.30000205 0.30000185 0.30000166 0.30000149 0.30000135
#  0.30000121 0.30000109 0.30000098 0.30000088 0.30000079 0.30000071
#  0.30000064 0.30000058 0.30000052 0.30000047 0.30000042 0.30000038
#  0.30000034 0.30000031 0.30000028 0.30000025 0.30000022 0.3000002
#  0.30000018 0.30000016 0.30000015 0.30000013 0.30000012 0.30000011
#  0.3000001  0.30000009 0.30000008 0.30000007 0.30000006 0.30000006
#  0.30000005 0.30000005 0.30000004 0.30000004 0.30000003 0.30000003
#  0.30000003 0.30000002 0.30000002 0.30000002 0.30000002 0.30000002
#  0.30000001 0.30000001 0.30000001 0.30000001 0.30000001 0.30000001
#  0.30000001 0.30000001 0.30000001 0.30000001 0.30000001 0.3
#  0.3        0.3        0.3       ]

# %%
'''
修改 gd1.py 的損失函數如下，設定不同的起始點，是否可找到區域最小值(local minimum)
損失函數 = 2x4-3x2+2x-20
'''
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return (-5*x**2+3*x+6)

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return -(10*x-3)

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x -= v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 5   
# 執行週期數
epochs = 200 
# 學習率   
lr = 0.01   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-5, 5.0, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [5.         4.53       4.107      3.7263     3.38367    3.075303
#  2.7977727  2.54799543 2.32319589 2.1208763  1.93878867 1.7749098
#  1.62741882 1.49467694 1.37520925 1.26768832 1.17091949 1.08382754
#  1.00544479 0.93490031 0.87141028 0.81426925 0.76284232 0.71655809
#  0.67490228 0.63741205 0.60367085 0.57330376 0.54597339 0.52137605
#  0.49923844 0.4793146  0.46138314 0.44524483 0.43072034 0.41764831
#  0.40588348 0.39529513 0.38576562 0.37718906 0.36947015 0.36252313
#  0.35627082 0.35064374 0.34557937 0.34102143 0.33691929 0.33322736
#  0.32990462 0.32691416 0.32422274 0.32180047 0.31962042 0.31765838
#  0.31589254 0.31430329 0.31287296 0.31158566 0.3104271  0.30938439
#  0.30844595 0.30760135 0.30684122 0.3061571  0.30554139 0.30498725
#  0.30448852 0.30403967 0.3036357  0.30327213 0.30294492 0.30265043
#  0.30238539 0.30214685 0.30193216 0.30173895 0.30156505 0.30140855
#  0.30126769 0.30114092 0.30102683 0.30092415 0.30083173 0.30074856
#  0.3006737  0.30060633 0.3005457  0.30049113 0.30044202 0.30039782
#  0.30035803 0.30032223 0.30029001 0.30026101 0.30023491 0.30021142
#  0.30019027 0.30017125 0.30015412 0.30013871 0.30012484 0.30011235
#  0.30010112 0.30009101 0.30008191 0.30007372 0.30006634 0.30005971
#  0.30005374 0.30004837 0.30004353 0.30003918 0.30003526 0.30003173
#  0.30002856 0.3000257  0.30002313 0.30002082 0.30001874 0.30001686
#  0.30001518 0.30001366 0.30001229 0.30001106 0.30000996 0.30000896
#  0.30000807 0.30000726 0.30000653 0.30000588 0.30000529 0.30000476
#  0.30000429 0.30000386 0.30000347 0.30000312 0.30000281 0.30000253
#  0.30000228 0.30000205 0.30000185 0.30000166 0.30000149 0.30000135
#  0.30000121 0.30000109 0.30000098 0.30000088 0.30000079 0.30000071
#  0.30000064 0.30000058 0.30000052 0.30000047 0.30000042 0.30000038
#  0.30000034 0.30000031 0.30000028 0.30000025 0.30000022 0.3000002
#  0.30000018 0.30000016 0.30000015 0.30000013 0.30000012 0.30000011
#  0.3000001  0.30000009 0.30000008 0.30000007 0.30000006 0.30000006
#  0.30000005 0.30000005 0.30000004 0.30000004 0.30000003 0.30000003
#  0.30000003 0.30000002 0.30000002 0.30000002 0.30000002 0.30000002
#  0.30000001 0.30000001 0.30000001 0.30000001 0.30000001 0.30000001
#  0.30000001 0.30000001 0.30000001 0.30000001 0.30000001 0.3
#  0.3        0.3        0.3       ]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return -5*x**2+3*x+6

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return 10*x-3 
"""註解by賴顗中: 這邊把函數乘上-1做微分
故底下(30行)xs 沒有乘上-1"""

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 5   
# 執行週期數
epochs = 200 
# 學習率   
lr = 0.01   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-5, 5.0, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()

# %% [markdown]
# ## gd1_lab2

# %%
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=x^2
def func(x): return 2*x**4-3*x+2*x-20

# 目標函數一階導數:dy/dx=2*x
def dfunc(x): return 8*x**3-6*x+2

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 5   
# 執行週期數
epochs = 1000 
# 學習率   
lr = 0.001   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-5, 5, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [5.         4.028      3.52734056 ... 0.57075639 0.57069348 0.57063068]

# %% [markdown]
# ## gd1_lab3

# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
x = Symbol('x')
y = sin(x)* E ** (-0.1*(x-0.6)**2)
yprime = y.diff(x)

# 目標函數:y=x^2
def func(x): return np.sin(x)*np.exp(-0.1*(x-0.6)**2)

# 目標函數一階導數:dy/dx=2*x
def dfunc(x_value): return yprime.subs(x, x_value).evalf()

def GD(x_start, df, epochs, lr):    
    """  梯度下降法。給定起始點與目標函數的一階導函數，求在epochs次反覆運算中x的更新值
        :param x_start: x的起始點    
        :param df: 目標函數的一階導函數    
        :param epochs: 反覆運算週期    
        :param lr: 學習率    
        :return: x在每次反覆運算後的位置（包括起始點），長度為epochs+1    
     """    
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v = -1*dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 0.3   
# 執行週期數
epochs = 1000 
# 學習率   
lr = 0.01   
# 梯度下降法 
# *** Function 可以直接當參數傳遞 ***
x = GD(x_start, dfunc, epochs, lr=lr) 
print (x)
# 輸出：[-5.     -2.     -0.8    -0.32   -0.128  -0.0512]

color = 'r'    
#plt.plot(line_x, line_y, c='b')    
from numpy import arange
t = arange(-5, 5, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [ 0.3         0.29035651  0.28069091 ... -1.22127504 -1.2212766
#  -1.22127814]
